# %% [markdown]
# # Lab: Khởi tạo, sao chép và lưu trữ dữ liệu bằng Pandas

# %% [markdown]
# # 1. Khởi tạo

# %% [markdown]
# ## 1.1. Series

# %% [markdown]
# ### 1.1.1. Khởi tạo bằng List

# %%
import pandas as pd

# %%
# Yêu cầu: Hãy tạo một list fruits chứa các phần tử lần lượt là 'Apple', 'Banana', 'Cherry'
fruits_list = ['Apple', 'Banana', 'Cherry']

# Yêu cầu: Hãy tạo một Series từ list fruits
fruits = pd.Series(fruits_list)
fruits
# Out:
# 0     Apple
# 1    Banana
# 2    Cherry
# dtype: object

# %%
# Yêu cầu: Hãy tạo một list ratings chứa các đánh giá lần lượt là 5, 3, 2, 1, 4, 3
ratings_list = [5,3,2,1,4,3]

# Yêu cầu: Hãy tạo một Series từ list ratings
ratings = pd.Series(ratings_list)
ratings
# Out:
# 0    5
# 1    3
# 2    2
# 3    1
# 4    4
# 5    3
# dtype: int64

# %% [markdown]
# ### 1.1.2. Khởi tạo bằng Dictionary

# %%
fruits_abc_dict = {'A': 'Apple',
                   'B': 'Banana',
                   'C': 'Cherry'}

# Yêu cầu: Hãy tạo một Series từ dictionary fruits_abc_dict
fruits_abc = pd.Series(fruits_abc_dict)
fruits_abc
# Out:
# A     Apple
# B    Banana
# C    Cherry
# dtype: object

# %% [markdown]
# ### 1.1.3. Khởi tạo đọc file

# %%
# Yêu cầu: Hãy tạo một Series App Name từ Google_Playstore.csv
import pandas as pd
app_name = pd.read_csv("sample_data/Google_Playstore.csv", usecols=["App Name"])
app_name = app_name.squeeze()
app_name.head()
# Out:
# 0                                              Gakondo
# 1                                  Ampere Battery Info
# 2                                               Vibook
# 3    Smart City Trichy Public Service Vehicles 17UC...
# 4                                              GROW.me
# Name: App Name, dtype: object

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 1.2. DataFrame

# %% [markdown]
# ### 1.2.1. Khởi tạo bằng List

# %%
import pandas as pd
sales_list = [('Apple', 'Fruit', 10),
              ('Hamburger', 'Fast Food', 20),
              ('Pepsi', 'Drinks', 10)]

# Yêu cầu: Hãy tạo một DataFrame từ list sales trên với tên cột lần lượt là Item, Type, Price
sales = pd.DataFrame(sales_list, columns=['Item', 'Type', 'Price'])
sales
# Out:
#         Item       Type  Price
# 0      Apple      Fruit     10
# 1  Hamburger  Fast Food     20
# 2      Pepsi     Drinks     10

# %% [markdown]
# ### 1.2.2. Khởi tạo bằng Dictionary

# %%
sales_dict= {
    'Name': ['Apple', 'Hamburger', 'Pepsi'],
    'Type': ['Fruit', 'Fast Food', 'Drinks'],
    'Price': [10, 20, 10]
}

# Yêu cầu: Hãy tạo một DataFrame từ dictionary sales trên
sales_2 = pd.DataFrame(sales_dict)
sales_2
# Out:
#         Name       Type  Price
# 0      Apple      Fruit     10
# 1  Hamburger  Fast Food     20
# 2      Pepsi     Drinks     10

# %% [markdown]
# ### 1.2.3. Khởi tạo bằng đọc file

# %%
# Yêu cầu: Hãy tạo một DataFrame từ Google_Playstore.csv
df_google_playstore = pd.read_csv("Google_Playstore.csv")
df_google_playstore.head()
# Out:
# <ipython-input-19-28c11dc1948b>:2: DtypeWarning: Columns (20,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_google_playstore = pd.read_csv("Google_Playstore.csv")
#          rt Hockey: Multiplayer Drawing Sport  \
# 0                          Radio Suara Dakwah
# 1                            D5T5 Race & Quiz
# 2                Санкт-Петербург за один день
# 3           INDIAN CONSTITUTION - a reference
# 4  MolsPay - Recharge,Bill Payment & Shopping
#
#                 com.pandaqi.art_hockey          Sports  0.0      0      10+  \
# 0          com.alhasmedia.swradakwah17   Entertainment  4.5   11.0     100+
# 1                       com.d5t5.racer          Racing  3.2   14.0   1,000+
# 2                      ru.mobiskif.spb  Travel & Local  0.0    0.0     100+
# 3  com.indianpolity.indianconstitution       Education  0.0    0.0      10+
# 4                        molsindia.com        Shopping  3.7  173.0  10,000+
#
#         10     19  True  0.1  ... http://pandaqi.com/art-hockey  \
# 0    100.0    283  True  0.0  ...         http://alhastream.com
# 1   1000.0   1278  True  0.0  ...               http://d5t5.com
# 2    100.0    393  True  0.0  ...   https://mobiskif.github.io/
# 3     10.0     21  True  0.0  ...                           NaN
# 4  10000.0  11660  True  0.0  ...      http://www.molsindia.com
#
#   askthepanda@pandaqi.com   Mar 2, 2020  Nov 25, 2020  Everyone  \
# 0    admin@alhastream.com  Sep 30, 2019  Sep 30, 2019  Everyone
# 1           info@d5t5.com  May 24, 2019  Feb 07, 2021  Everyone
# 2      mobiskif@gmail.com  Jul 20, 2018  Jun 01, 2018  Everyone
# 3     divspar04@gmail.com  Mar 18, 2021  Apr 06, 2021  Everyone
# 4  molsindia050@gmail.com  Nov 17, 2017  Mar 27, 2019  Everyone
#
#   http://pandaqi.com/privacy_policies/art_hockey_pp.html True.1  False  \
# 0  http://alhastream.com/kebijakan-privasi-radio-...      False  False
# 1  https://d5t5.com/article/d5t5-racer-privacy-po...      False  False
# 2              https://mobiskif.github.io/policy.txt      False  False
# 3                                                NaN       True  False
# 4           https://molsindia.com/privacy-policy.php      False  False
#
#   False.1  2021-06-15 20:51:31
# 0   False  2021-06-15 20:51:31
# 1   False  2021-06-15 20:51:31
# 2   False  2021-06-15 20:51:31
# 3   False  2021-06-15 20:51:32
# 4   False  2021-06-15 20:51:32
#
# [5 rows x 24 columns]

# %% [markdown]
# # 2. Thêm cột dữ liệu

# %%
sales.head()
# Out:
#         Item       Type  Price
# 0      Apple      Fruit     10
# 1  Hamburger  Fast Food     20
# 2      Pepsi     Drinks     10

# %%
count = [1, 2, 3]
sale_list = sales.head()
# Yêu cầu: Hãy thêm cột số lượng bán cho DataFrame sales từ List trên
sales = pd.DataFrame(sale_list, columns=['Item', 'Type', 'Price'])

sales
# Out:
#         Item       Type  Price
# 0      Apple      Fruit     10
# 1  Hamburger  Fast Food     20
# 2      Pepsi     Drinks     10

# %%
rating = pd.Series([5, 3, 2])
# Yêu cầu: Hãy thêm cột đánhg giá cho DataFrame sales Series trên
...
sales = pd.DataFrame(sales_list, columns=['Item', 'Type', 'Price'])
sales['Đánh giá'] = rating
sales
# Out:
#         Item       Type  Price  Đánh giá
# 0      Apple      Fruit     10         5
# 1  Hamburger  Fast Food     20         3
# 2      Pepsi     Drinks     10         2

# %% [markdown]
# # 3. Tạo bản sao tập dữ liệu

# %% [markdown]
# ## 3.1. Series

# %%
# Yêu cầu: Hãy tạo một bản sao Series new_ratings từ Series ratings
new_ratings = ratings.copy()
new_ratings
# Out:
# 0    5
# 1    3
# 2    2
# 3    1
# 4    4
# 5    3
# dtype: int64

# %% [markdown]
# ## 3.2. DataFrame

# %%
# Yêu cầu: Hãy tạo một bản sao DataFrame new_df_google_playstore từ DataFrame df_google_playstore
new_df_google_playstore = df_google_playstore.copy()
new_df_google_playstore.head()
# Out:
#          rt Hockey: Multiplayer Drawing Sport  \
# 0                          Radio Suara Dakwah
# 1                            D5T5 Race & Quiz
# 2                Санкт-Петербург за один день
# 3           INDIAN CONSTITUTION - a reference
# 4  MolsPay - Recharge,Bill Payment & Shopping
#
#                 com.pandaqi.art_hockey          Sports  0.0      0      10+  \
# 0          com.alhasmedia.swradakwah17   Entertainment  4.5   11.0     100+
# 1                       com.d5t5.racer          Racing  3.2   14.0   1,000+
# 2                      ru.mobiskif.spb  Travel & Local  0.0    0.0     100+
# 3  com.indianpolity.indianconstitution       Education  0.0    0.0      10+
# 4                        molsindia.com        Shopping  3.7  173.0  10,000+
#
#         10     19  True  0.1  ... http://pandaqi.com/art-hockey  \
# 0    100.0    283  True  0.0  ...         http://alhastream.com
# 1   1000.0   1278  True  0.0  ...               http://d5t5.com
# 2    100.0    393  True  0.0  ...   https://mobiskif.github.io/
# 3     10.0     21  True  0.0  ...                           NaN
# 4  10000.0  11660  True  0.0  ...      http://www.molsindia.com
#
#   askthepanda@pandaqi.com   Mar 2, 2020  Nov 25, 2020  Everyone  \
# 0    admin@alhastream.com  Sep 30, 2019  Sep 30, 2019  Everyone
# 1           info@d5t5.com  May 24, 2019  Feb 07, 2021  Everyone
# 2      mobiskif@gmail.com  Jul 20, 2018  Jun 01, 2018  Everyone
# 3     divspar04@gmail.com  Mar 18, 2021  Apr 06, 2021  Everyone
# 4  molsindia050@gmail.com  Nov 17, 2017  Mar 27, 2019  Everyone
#
#   http://pandaqi.com/privacy_policies/art_hockey_pp.html True.1  False  \
# 0  http://alhastream.com/kebijakan-privasi-radio-...      False  False
# 1  https://d5t5.com/article/d5t5-racer-privacy-po...      False  False
# 2              https://mobiskif.github.io/policy.txt      False  False
# 3                                                NaN       True  False
# 4           https://molsindia.com/privacy-policy.php      False  False
#
#   False.1  2021-06-15 20:51:31
# 0   False  2021-06-15 20:51:31
# 1   False  2021-06-15 20:51:31
# 2   False  2021-06-15 20:51:31
# 3   False  2021-06-15 20:51:32
# 4   False  2021-06-15 20:51:32
#
# [5 rows x 24 columns]

# %% [markdown]
# # 4. Lưu dữ liệu sang file dữ liệu

# %% [markdown]
# ## 4.1. Series

# %%
# Yêu cầu: Hãy lưu trữ Series fruits sang file csv
fruits.to_csv('fruits.csv', index = False)

# Yêu cầu: Hãy lưu trữ Series ratings sang file excel
ratings.to_excel('ratings.xlsx', index = False)

# Yêu cầu: Hãy lưu trữ Series fruits_abc sang file json
fruits_abc.to_json('fruits_abc.json')

# %% [markdown]
# ## 4.2. DataFrame

# %%
# Yêu cầu: Hãy lưu trữ DataFrame sales sang file csv
sales.to_csv('sales.csv', index=False)

# Yêu cầu: Hãy lưu trữ DataFrame sales sang file excel
sales.to_excel('sales.xlsx', index=False)

# Yêu cầu: Hãy lưu trữ DataFrame sales sang file json
sales.to_json('sales.json')
